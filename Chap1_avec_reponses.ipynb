# %% [markdown]
# # <span style="color:green"><ins>Introduction</ins></span>

# %% [markdown]
# Dans ce cours, nous utiliserons Python 3, qui n'est pas rétrocompatible avec Python 2 et Python 1.

# %% [markdown]
# Contrairement à d’autres langages comme Matlab, Python est un langage fortement typé, il est donc important de connaitre les différents types de données, les opérations qu’on peut leur appliquer, et comment passer d’un type à un autre. Cela sera traité en détail au chapitre 3.

# %% [markdown]
# Ceci est une cellule (cell), qui peut contenir soit du code soit du texte, à sélectionner dans le menu déroulant dans la barre d'options ci-dessus (code ou markdown).

# %% [markdown]
# Notions de base en markdown : https://www.markdownguide.org/basic-syntax/

# %% [markdown]
# Pour insérer une figure (format png): créer une cellule markdown, puis cliquer sur Edit -> Insert image

# %% [markdown]
# Pour exécuter le code, 3 façons de faire:
# - cliquer sur la cellule dont on veut faire tourner le code et cliquer sur "exécuter" dans la barre d'options. Mais si la cellule dépend d'autres cellules et qu'on la fait tourner plusieurs fois seule, le résultat peut être faux. Dans ce cas, les deux autres façons de faire sont à privilégier.
# - Faire tourner toutes les cellules depuis le début: Cell -> Run all
# - Effacer toutes les variables en mémoire et faire tourner toutes les cellules depuis le début: Kernel -> restart and run all

# %%
# Ceci est un commentaire en python

# %% [markdown]
# Au début du code, toujours importer les bibliothèques (ou librairies) nécessaires (cela peut se faire plus loin dans le code également, mais c'est plus clair en début fichier):

# %%
import numpy as np                        # pour les opérations mathématiques de base
import matplotlib.pyplot as plt           # pour les graphiques. On importe uniquement le module pyplot, qui suffit en général
import scipy.optimize as sciop            # scipy est une bibliothèque pour les opérations mathématiques + avancées, comme des calculs d'optimisation ou d'analyse numérique. Nous utiliserons le module optimize de scipy
import scipy.interpolate as scint         # pour les calculs d'interpolation (exercice 7)

# %% [markdown]
# Les biblothèques/modules sont renommés pour en faciliter l'usage. Par exemple, pour utiliser la fonction racine carrée de numpy, on écrira `np.sqrt()`.
# Pour la liste des fonctions disponibles et leur utilisations, une recherche rapide sur google est le plus facile et rapide. Privilégier les liens vers les sites webs officiels de python et des librairies :
# - https://numpy.org/doc/stable/user/index.html#user
# - https://docs.scipy.org/doc/scipy/tutorial/index.html#user-guide
# - https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html
#
# Si votre langage de base est le Matlab, un tableau d'équivalence avec les fonctions numpy est disponible sous le lien suivant :
# https://numpy.org/doc/stable/user/numpy-for-matlab-users.html

# %%
# !python --version      # version de python
# Out:
# Python 3.10.9

# %% [markdown]
# Pour enregistrer votre fichier ipython, cliquer sur "File" puis "Save as", et donner un nom à votre fichier, suivi de l'extension ipynb, par exemple : chapitre1.ipynb<br>
# Autre possibilité : "File" puis "Download as", qui vous permet de télécharger votre fichier en html, ipython (extension ipynb) ou python classique (extension .py, à ouvrir avec le logiciel Spyder, disponible également sur anaconda). L'option pdf ne fonctionne pas.

# %% [markdown]
# Pour imprimer, le plus facile est de passer par le fichier html.

# %% [markdown]
# # <span style="color:green"><ins>Chapitre 1: Etude de fonctions à une variable</ins></span>

# %% [markdown]
# ## 1.1 Opérations et fonctions de base

# %% [markdown]
# ### Opérations algébriques de base:

# %%
6+7                 # Addition
7-9                 # Soustraction
9*5                 # Multiplication
6/5                 # Division
20//3               # Division entière
20%3                # Reste de la division entière (modulo)
divmod(20,3)        # Division entière et modulo
6**2                # 6 à la puissance 2
7.8                 # Toujours le "point" pour les décimales
-5.4                # Nombre négatif
.006                # signifie 0.006
3.6e5               # signifie 3.6*10**5
3.6e-5              # signifie 3.6*10**-5
abs(3-20)           # valeur absolue
1j                  # nombre complexe "i"
9+10j               # exemple de nombre complexe
(9+10j).real        # partie réelle du nombre complexe
(9+10j).imag        # partie imaginaire du nomnbre complexe
# Out:
# 10.0

# %% [markdown]
# Comme on peut le constater, ipython n'affiche pas la réponse lorsqu'on fait tourner la cellule. Pour ce faire, il faut appliquer `print()` :

# %%
print(6+7)                 # Addition
print(7-9)                 # Soustraction
print(9*5)                 # Multiplication
print(6/5)                 # Division
print(20//3)               # Division entière
print(20%3)                # Reste de la division entière (modulo)
print(divmod(20,3))        # Division entière et modulo
print(6**2)                # 6 à la puissance 2
print(7.8)                 # Toujours le "point" pour les d√©cimales
print(-5.4)                # Nombre n√©gatif
print(.006)                # signifie 0.006
print(3.6e5)               # signifie 3.6*10**5
print(3.6e-5)              # signifie 3.6*10**-5
print(abs(3-20))           # valeur absolue
print(1j)                  # nombre complexe "i"
print(9+10j)               # exemple de nombre complexe
print((9+10j).real)        # partie réelle du nombre complexe
print((9+10j).imag)        # partie imaginaire du nomnbre complexe
# Out:
# 13
# -2
# 45
# 1.2
# 6
# 2
# (6, 2)
# 36
# 7.8
# -5.4
# 0.006
# 360000.0
# 3.6e-05
# 17
# 1j
# (9+10j)
# 9.0
# 10.0

# %% [markdown]
# ### Affectation

# %%
x=7                 # On assigne le nombre 7 à la variable x, i.e. x<-7
print(x)            
y=2*x               # => y=14
print(y)
x=3                 
print(y)            # y n'est pas modifié si x l'est (pas de lien type "orienté objet")
x=x+2               # signifie x<-x+2
print(x)
x+=2                # Notation abrégée de x=x+2 ; existe aussi avec -, *, /, **, %, //
print(x)
x=y=z=5             # Notation autorisée
print(x,y,z)
x,y,z=3.2,4.9,8     # Notation autorisée
print(x,y,z)
# Out:
# 7
# 14
# 14
# 5
# 7
# 5 5 5
# 3.2 4.9 8

# %% [markdown]
# ### Suppression de variable

# %%
del x               # supprimer une variable en mémoire
# print(x)

# %% [markdown]
# ### Quelques fonctions prédéfinies (via numpy)

# %%
print(np.sqrt(4))          # Racine carrée 
print(np.exp(5))           # Exponentielle
print(np.log(np.exp(5)))   # logarithme népérien
print(np.log2(8))          # log en base 2
print(np.log10(1000))      # log en base 10
print(np.pi)               # Nombre pi
print(np.sin(np.pi))       # sinus ; angle toujours en radians
print(np.cos(np.pi))       # cosinus
print(np.tan(np.pi))       # tangente
# Out:
# 2.0
# 148.4131591025766
# 5.0
# 3.0
# 3.0
# 3.141592653589793
# 1.2246467991473532e-16
# -1.0
# -1.2246467991473532e-16

# %% [markdown]
# ### Interagir avec l'utilisateur

# %% [markdown]
# La fonction `input()`permet de communiquer avec l'utilisateur qui doit réaliser une saisie au clavier. Le programme est interrompu tant que l'utilisateur n'a pas appuyé sur `Enter` au clavier. La valeur retournée est **toujours du texte**. On le converti en nombre entier avec int() ou en nombre réel avec float().

# %%
r=float(input('Que vaut le rayon du cercle ? '))   # Répondre à la question
# float transforme une chaïne de caractère en floating point number ("nombre réel")
P=2*np.pi*r
print("Périmètre = "+str(P))   # str pour transformer un nombre en chaïne de caractères 
# ou plus direct :
print("Périmètre = ",P)
# Out:
# Que vaut le rayon du cercle ? 9
# Périmètre = 56.548667764616276
# Périmètre =  56.548667764616276

# %% [markdown]
# ## 1.2 Exercice 1

# %% [markdown]
# Evaluez
# \begin{equation}
# f(x)=\frac{\sqrt{1+\pi}\sin(\exp(x^3)+1)}{(\ln(x^2)+1)^{3/2}}
# \end{equation}
# en $x=-1.2$.

# %%
x=-1.2
y=np.sqrt(1+np.pi)*np.sin(np.exp(x**3)+1)/(np.log(x**2)+1)**(3/2)
print(y)
# Out:
# 1.1792013763961584

# %% [markdown]
# ## 1.3 Graphe d'une fonction : exemple

# %% [markdown]
# Représentez le graphe de la fonction
# \begin{equation}
# f:[-1,1]\rightarrow\mathbb{R}:x\rightarrow\frac{1}{1+25 x^2}
# \end{equation}
# Dessinez le graphe en noir et en trait continu.<br />
# Ajoutez une grille à votre graphe, donnez un nom aux axes et un titre au graphe.<br />
# Changez les bornes des axes pour faire un zoom de votre choix.

# %%
x=np.linspace(-1,1,2001)

# %% [markdown]
# Le vecteur x ainsi créé représente la grille de points en abscisse, grille linéairement espacée de x=-1 (inclus) à x=1 (inclus), avec 2001 points au total.<br />
# Pour voyager dans le vecteur x:

# %%
print(x)
print(type(x))
print(len(x))      # Longueur du vecteur
print(x[0])        # premier indice vaut toujours 0
print(x[0:3])      # indices 0 à 2 (3 non compris!!!)
print(x[:3])       # Idem
print(x[3:])       # Indice 3 compris jusqu'à la fin
print(x[-1])       # Dernière valeur de x
print(x[4:12:2])   # De l'élément 4 jusqu'à l'élément 12 non compris, par pas de 2
print(x[::2])      # 1 valeur sur 2 sur tout le vecteur
print(x[::-1])     # Vecteur dans l'autre sens - très utile pour passer de ordre croissant à décroissant
# Out:
# [-1.    -0.999 -0.998 ...  0.998  0.999  1.   ]
# <class 'numpy.ndarray'>
# 2001
# -1.0
# [-1.    -0.999 -0.998]
# [-1.    -0.999 -0.998]
# [-0.997 -0.996 -0.995 ...  0.998  0.999  1.   ]
# 1.0
# [-0.996 -0.994 -0.992 -0.99 ]
# [-1.    -0.998 -0.996 ...  0.996  0.998  1.   ]
# [ 1.     0.999  0.998 ... -0.998 -0.999 -1.   ]

# %%
y=1/(1+25*x**2)

# %%
plt.plot(x,y,"k")                               #"k" pour couleur noire
plt.grid()                                      # Quadrillage en arrière plan
plt.xlabel("mon axe x")
plt.ylabel("mon super axe y")
plt.title("Mon méga super beau graphe")
#plt.close()                                    # Pour fermer la figure (ne s'affiche donc pas)
# Out:
# Text(0.5, 1.0, 'Mon méga super beau graphe')

# %% [markdown]
# On se référera à la documentation officielle de "matplotlib pyplot plot" sur le web pour les options graphiques (couleurs, motifs, ...).

# %%
plt.plot(x,y,"k")
plt.axis([-0.2, 0.2, 0.7,1])    # zoom de -0.2 à 0.2 selon x et 0.7 à 1 selon y
# NB: au lieu de plt.axis, pour restreindre uniquement l'axe x, on utilise plt.xlim, et plt.ylim pour l'axe y
plt.grid()

# %% [markdown]
# Un clic droit sur la figure permet de l'enregistrer sous format png

# %% [markdown]
# ### Autre façon 1 : travailler avec une ***fonction*** python, via "def"

# %% [markdown]
# Privilégier cette façon de faire ou la suivante, qui permettent d'effectuer des opérations sur la fonction ainsi créée, comme des recherches de racine ou d'extrema (voir ci-dessous)

# %%
x=np.linspace(-1,1,2001)
def f(x): return 1/(1+25*x**2)
plt.plot(x,f(x),"k")                               
plt.grid()                                   
plt.xlabel("mon axe x")
plt.ylabel("mon super axe y")
plt.title("Mon méga super beau graphe")
#plt.close()
# Out:
# Text(0.5, 1.0, 'Mon méga super beau graphe')

# %% [markdown]
# ### Autre façon 2 : travailler avec une ***fonction anonyme*** python, via "lambda"

# %%
x=np.linspace(-1,1,2001)
f=lambda x: 1/(1+25*x**2)
plt.plot(x,f(x),"k")                               
plt.grid()                                   
plt.xlabel("mon axe x")
plt.ylabel("mon super axe y")
plt.title("Mon méga super beau graphe")
#plt.close()
# Out:
# Text(0.5, 1.0, 'Mon méga super beau graphe')

# %% [markdown]
# ## 1.4 Localiser les extrema d'une fonction : exemple

# %% [markdown]
# Représentez le graphe de la fonction
# \begin{equation}
# f:[-3,3]\rightarrow\mathbb{R}:x\rightarrow(1+x)\exp(-x^2+3x\cos(x))-(1+x^4)^2\sin(x)
# \end{equation}
# Dessinez le graphe en rouge et en pointillés.<br />
# Ajoutez une grille à votre graphe.<br />
# Trouvez tous les extrema de la fonction sur $[-3,3]$ à l'aide de la fonction prédéfinie `fmin` de scipy.optimize<br />
# Evaluez la fonction en ses extrema : donnez leurs coordonnées.<br />
# Ajoutez au graphe une croix sur chaque extremum, et notez "minimum" ou "maximum" en dessous à l'aide de la fonction prédéfinie `text` de matplotlib.pyplot.

# %%
def f(x): return (1+x)*np.exp(-x**2+3*x*np.cos(x))-(1+x**4)**2*np.sin(x)
# Graphe
x=np.linspace(-3,3,1000)
plt.plot(x,f(x),"r:")
plt.grid()
# Minimum de la fonction
xmin=sciop.fmin(f,3)   # 3 = first guess (valeur approchée de l'abscisse du minimum, par simple inspection visuelle du graphe). Cette fonction renvoie avec grande précision le x tel que f(x) est min.
print("Le minimum de la fonction a pour coordonnées (",xmin,",",f(xmin),")")
plt.plot(xmin,f(xmin),"kx",markersize=10)
plt.text(xmin-1,f(xmin),"Minimum",color="m")
# Maximum de la fonction
def g(x): return -f(x)
xmax=sciop.fmin(g,-3)      # -3 = first guess. Renvoie avec grande précision le x tel que -f(x) est min, c-à-d tel que f(x) est max 
# les 2 lignes précédentes peuvent s'écrire + simplement en 1 ligne: xmax=sciop.fmin(lambda x: -f(x),-3)
print("Le maximum de la fonction a pour coordonnées (",xmax,",",f(xmax),")")
plt.plot(xmax,f(xmax),"kx",markersize=10)
plt.text(xmax+0.2,f(xmax),"Maximum",color="m")
# Out:
# Optimization terminated successfully.
#          Current function value: -1307.107513
#          Iterations: 13
#          Function evaluations: 26
# Le minimum de la fonction a pour coordonnées ( [2.79990234] , [-1307.10751293] )
# Optimization terminated successfully.
#          Current function value: -1305.168176
#          Iterations: 13
#          Function evaluations: 26
# Le maximum de la fonction a pour coordonnées ( [-2.79975586] , [1305.16817616] )
# Text([-2.59975586], [1305.16817616], 'Maximum')

# %% [markdown]
# ## 1.5 Ajouter une légende et localiser les racines : exemple

# %% [markdown]
# Représentez dans un même diagramme, les graphes des fonctions
# \begin{equation}
# f(x)=\sin(x^2)\quad\textrm{et}\quad g(x)=\frac{\exp(x)}{4}
# \end{equation}
# pour $x\in[0,2]$.<br />
# Ajoutez une légende.<br />
# Localisez grossièrement à l'aide de la figure les valeurs de $x$ telles que $\sin(x^2)=\frac{\exp(x)}{4}$. Calculez-les ensuite précisément avec la fonction prédéfinie `scipy.optimize.fsolve`.

# %%
def f(x): return np.sin(x**2)
def g(x): return np.exp(x)/4
x=np.linspace(0,2,1000)
plt.plot(x,f(x),label="sin(x**2)")
plt.plot(x,g(x),label="exp(x)/4")
plt.legend()
plt.grid()

# %% [markdown]
# f(x)=g(x) lorsque h(x)=f(x)-g(x)=0. Il suffit donc de chercher les racines de la fonction h, à l'aide de la fonction prédéfinie `fsolve` de scipy optimize. Comme pour `fmin`, il faut donner à cette fonction un first guess après inspection visuelle sur le graphe.

# %%
def h(x): return f(x)-g(x)
racine1=sciop.fsolve(h,0.75)
racine2=sciop.fsolve(h,1.3)
print("Entre 0 et 2, les deux racines sont ",racine1," et ",racine2)
# Out:
# Entre 0 et 2, les deux racines sont  [0.74452119]  et  [1.35250872]

# %% [markdown]
# ## 1.6 Interpolation de données : exemple

# %% [markdown]
# Le tableau ci-dessous donne la force électromotrice $E$ en volts d'une pile en fonction de la température absolue $T$ en Kelvin.
#
# |T|290|300|310|320|330|
# |-|-|-|-|-|-|
# |E|1,15053|1,14950|1,14488|1,14403|1,14325|
#
# Représentez les points correspondants aux données dans un graphe adéquat.<br />
# Utilisez les méthodes d'interpolation linéaire et spline cubique pour relier les points entre eux, à l'aide de la fonction prédéfinie `interp1d` de `scipy.interpolate`.

# %%
T=np.array([290,300,310,320,330])
E=np.array([1.15053,1.14950,1.14488,1.14403,1.14325])
plt.plot(T,E,"b",label="interp linéaire")   # Interpolation faite par défaut graphiquement
plt.plot(T,E,"ro")
f=scint.interp1d(T,E,"cubic")    # f est la fonction d'interpolation par splines cubiques passant les points de coordonnées (T,E)
Tinterp=np.linspace(290,330,100)  
#print(Tinterp)
plt.plot(Tinterp,f(Tinterp),"g",label="interp spline cubique")
plt.xlabel("T(K)")
plt.ylabel("E(V)")
plt.grid()
plt.legend()

# %% [markdown]
# ## 1.7 Exercice 2

# %% [markdown]
# On a mesuré la différence de potentiel en fonction du courant dans une cellule photovoltaïque. Les 14 points de mesure se trouvent ci-dessous. On aimerait connaître la valeur du courant pour laquelle la puissance est maximale et la valeur de cette puissance maximale. Comme nous n'avons que 14 mesures, il est judicieux d'interpoler les données afin d'estimer au mieux ces valeurs.
#
# |I(mA)|0.00|0.07|0.73|1.43|3.41|6.01|7.32|7.59|7.68|7.77|7.81|7.88|7.91|7.92|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|
# |V(mV)|745|744|736|729|696|615|460|331|258|187|151|98.6|67.6|46.4|
#
# <ol>
# <li>Faites le graphe de la puissance en fonction du courant pour ces 14 points de données afin d'avoir une idée grossière de la courbe continue sous-jacente (rappel : $P=VI$).</li>
# <li>Testez les méthodes d'interpolation suivantes: linéaire et spline.</li>
# <li>Sur chacune de vos courbes interpolées, localisez le maximum via fmin (de scipy.optimize) et reportez ce point sur votre graphe de la puissance en fonction du courant (le point doit être bien visible).</li>
# </ol>

# %%
# Courants
I=np.array([0.00,0.07,0.73,1.43,3.41,6.01,7.32,7.59,7.68,7.77,7.81,7.88,7.91,7.92])
# Tensions
U=np.array([745,744,736,729,696,615,460,331,258,187,151,98.6,67.6,46.4])

# %%
# Puissance expérimentale
P=U*I

# %% [markdown]
# ### Graphe des points expérimentaux

# %%
plt.plot(I,P,"ro")
plt.grid()
plt.xlabel("Courant (mA)")
plt.ylabel("Puissance ($\mu$W)")
# Out:
# Text(0, 0.5, 'Puissance ($\\mu$W)')

# %% [markdown]
# ### Fonctions d'interpolation

# %%
y_linear=scint.interp1d(I,P,"linear")
y_cubic=scint.interp1d(I,P,"cubic")

# %% [markdown]
# ### Recherche du max sur chaque courbe d'interpolation

# %%
# Inversion fonction pour recherche min à la place de recherche max
y_linear_m=lambda x: -y_linear(x)
y_cubic_m=lambda x: -y_cubic(x)
xmax_linear=sciop.fmin(y_linear_m,6)
xmax_cubic=sciop.fmin(y_cubic_m,6)
# Out:
# Optimization terminated successfully.
#          Current function value: -3696.149922
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: -3909.738668
#          Iterations: 14
#          Function evaluations: 28

# %% [markdown]
# ### Graphe final

# %%
plt.plot(I,P,"ro",label="Data")
I_interp=np.linspace(I[0],I[-1],1000)     # abscisses pour tracer les courbes sur l'intervalle des courants
plt.plot(I_interp,y_linear(I_interp),label="Interpolation linéaire")
plt.plot(I_interp,y_cubic(I_interp),label="Interpolation par splines cubiques")
plt.plot(xmax_linear,y_linear(xmax_linear),"k*",markersize=10)
plt.plot(xmax_cubic,y_cubic(xmax_cubic),"k*",markersize=10)
plt.grid()
plt.xlabel("Courant (mA)")
plt.ylabel("Puissance ($\mu$W)")
plt.legend()
